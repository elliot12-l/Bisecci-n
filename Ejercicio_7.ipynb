# %% [markdown]
# <a href="https://colab.research.google.com/github/elliot12-l/Bisecci-n/blob/main/Ejercicio_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Metodo Bisection

# %%
from typing import Callable
def sign(x: float) -> int:
    if x > 0:
        return 1
    elif x < 0:
        return -1
    else:
        return 0

# %%
def bisection(
    a: float, b: float, *, equation: Callable[[float], float], tol: float, N: int
) -> tuple[float, float, float, int] | None:
    i = 1

    # Input validation
    # Comente a continuación y vea qué sucede
    assert a < b, "a not lower than b, the interval is not valid."

    # Comente a continuación y vea qué sucede
    assert (
        equation(a) * equation(b) < 0
    ), "The function does not change sign over the interval."

    Fa = equation(a)
    p = a # to avoid crash in i == 0.
    for i in range(N):

        # esta alternativa es suceptible de desborde, especialmente si a y b son muy grandes
        # p = (a + b)/2

        p = a + (b - a) / 2
        FP = equation(p)
        if FP == 0 or (b - a) / 2 < tol:
            return p, a, b, i

        if sign(Fa) * sign(FP) > 0:

            # esta alternativa podría causar también un desborde
            # if Fa * FP > 0:

            a = p
            Fa = FP
        else:
            b = p

    # Respuesta temporal
    return p, a, b, i

    # Es mejor usar esta opción, cuando el algoritmo no llega a una tolerancia en
    # las iteraciones dadas.

    # raise ValueError(
    #     "Solution not found within the given tolerance and number of iterations"
    # )

# %% [markdown]
# ## Ecuacion
#
# $s(t)=s_0-\frac{mg}{k}t+\frac{m^2g}{k^2}(1-e^{{-kt}/m})$
#
# luego sustituimos los valores
#
# $s(t)=300-\frac{0.25(9.81)}{0.1}t+\frac{0.25^2(9.81)}{0.1^2}(1-e^{{-0.1t}/0.25})$
#
# simplificamos
#
# $s(t)=300-24.525t+61.3125(1-e^{-0.4t})$
#
# Igualamos a 0
#
# $0=300-24.525t+61.3125(1-e^{-0.4t})$

# %%
def equation(x: float) -> float:
    term1 = np.e**(-0.4*x)
    return 300-24.525*x+31.3125*(1-term1)

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interactive


def plotting(a, b, i):
    x = np.linspace(a, b, 100)

    y = equation(x)
    x_i = x[0]
    try:
      x_i, a2, b2, i = bisection(a, b, equation=equation, tol=1e-2, N=i)
      all = True
    except Exception as e:
      all = False
      print(e)
      a2 = b2 = (a + b)/2

    ax = plt.gca()
    ax.cla()
    plt.plot(x, y);

    plt.xlabel('x');
    plt.ylabel('y');
    plt.title('Plot of $0=300-24.525t+61.3125(1-e^{-0.4t})$');
    plt.scatter(a, equation(a), color='blue', label='initial left lim');
    plt.scatter(b, equation(b), color='blue', label='initial right lim');
    if all:
      plt.scatter(a2, equation(a2), color='red')
      plt.scatter(b2, equation(b2), color='red')
      plt.scatter(x_i, 0, color='green', marker = "s", label='root');

      plt.hlines(0, a, b, colors= "black")
    plt.grid(True);
    plt.legend();

    plt.show();

interactive_plot = interactive(plotting, a=(-5,20,.1), b=(-5,20,.1), i=(0,11,1))
display(interactive_plot);
# Out:
# interactive(children=(FloatSlider(value=7.0, description='a', max=20.0, min=-5.0), FloatSlider(value=7.0, desc…
