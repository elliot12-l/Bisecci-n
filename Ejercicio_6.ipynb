# %% [markdown]
# <a href="https://colab.research.google.com/github/elliot12-l/Bisecci-n/blob/main/Ejercicio_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Metodo Bisection

# %%
from typing import Callable
def sign(x: float) -> int:
    if x > 0:
        return 1
    elif x < 0:
        return -1
    else:
        return 0

# %%
def bisection(
    a: float, b: float, *, equation: Callable[[float], float], tol: float, N: int
) -> tuple[float, float, float, int] | None:
    i = 1

    # Input validation
    # Comente a continuación y vea qué sucede
    assert a < b, "a not lower than b, the interval is not valid."

    # Comente a continuación y vea qué sucede
    assert (
        equation(a) * equation(b) < 0
    ), "The function does not change sign over the interval."

    Fa = equation(a)
    p = a # to avoid crash in i == 0.
    for i in range(N):

        # esta alternativa es suceptible de desborde, especialmente si a y b son muy grandes
        # p = (a + b)/2

        p = a + (b - a) / 2
        FP = equation(p)
        if FP == 0 or (b - a) / 2 < tol:
            return p, a, b, i

        if sign(Fa) * sign(FP) > 0:

            # esta alternativa podría causar también un desborde
            # if Fa * FP > 0:

            a = p
            Fa = FP
        else:
            b = p

    # Respuesta temporal
    return p, a, b, i

    # Es mejor usar esta opción, cuando el algoritmo no llega a una tolerancia en
    # las iteraciones dadas.

    # raise ValueError(
    #     "Solution not found within the given tolerance and number of iterations"
    # )

# %% [markdown]
# ## Ecuacion
# primero, dividimos ambos lados de la ecuacion por L
#
# $\frac{V}{L}=0.5 \pi r^2 - r^2 \arcsin(h/r)-h\sqrt{r^2-h^2}$
#
# luego sustituimos los valores
#
# $\frac{12.4}{10}=0.5 \pi 1^2 - 1^2 \arcsin(h/1)-h\sqrt{1^2-h^2}$
#
# simplificamos
#
# $1.24=0.5 \pi - \arcsin(h)-h \sqrt{1-h^2}$
#
# Igualamos a 0
# $0=0.5 \pi - \arcsin(h)-h \sqrt{1-h^2}-1.24$

# %%
def equation(x: float) -> float:
    term1 = 0.5 * np.pi
    term2 = np.arcsin(x)
    term3 = x * np.sqrt(1 - x**2)
    return term1 - term2 - term3 - 1.24

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interactive


def plotting(a, b, i):
    x = np.linspace(a, b, 100)

    y = equation(x)
    x_i = x[0]
    try:
      x_i, a2, b2, i = bisection(a, b, equation=equation, tol=1e-2, N=i)
      all = True
    except Exception as e:
      all = False
      print(e)
      a2 = b2 = (a + b)/2

    ax = plt.gca()
    ax.cla()
    plt.plot(x, y);

    plt.xlabel('x');
    plt.ylabel('y');
    plt.title('Plot of $0.5\pi-arcsin(h)-h\sqrt{1-h^2}-1.24 = 0$');
    plt.scatter(a, equation(a), color='blue', label='initial left lim');
    plt.scatter(b, equation(b), color='blue', label='initial right lim');
    if all:
      plt.scatter(a2, equation(a2), color='red')
      plt.scatter(b2, equation(b2), color='red')
      plt.scatter(x_i, 0, color='green', marker = "s", label='root');

      plt.hlines(0, a, b, colors= "black")
    plt.grid(True);
    plt.legend();

    plt.show();

interactive_plot = interactive(plotting, a=(-5,5,.1), b=(-5,5,.1), i=(0,11,1))
display(interactive_plot);
# Out:
# interactive(children=(FloatSlider(value=0.0, description='a', max=5.0, min=-5.0), FloatSlider(value=0.0, descr…
